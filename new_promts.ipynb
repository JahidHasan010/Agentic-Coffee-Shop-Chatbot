# %%
import os

# %%
from openai import OpenAI
import json
from sklearn.metrics.pairwise import cosine_similarity
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Set your Google API key (replace 'your_google_api_key' with your actual API key)
os.environ["GOOGLE_API_KEY"] = "AIzaSyAXH-phHgbd_zdEBMxXuEf6NVwAEcxDB6U"

# %%
client = OpenAI(
            api_key=os.getenv("GOOGLE_API_KEY"),
            base_url=os.getenv("https://generativelanguage.googleapis.com/v1beta/"),
        )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 client = OpenAI(
#       2             api_key=os.getenv("GOOGLE_API_KEY"),
#       3             base_url=os.getenv("https://generativelanguage.googleapis.com/v1beta/"),
#       4         )
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
#     124     version=__version__,
#     125     base_url=base_url,
#     126     max_retries=max_retries,
#     127     timeout=timeout,
#     128     http_client=http_client,
# ...

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = client.chat.completions.create(
    model="gemini-1.5-flash",
    n=1,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Explain to me how AI works"
        }
    ]
)

print(response.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 from openai import OpenAI
# ----> 3 client = OpenAI(
#       4     api_key=os.getenv("GOOGLE_API_KEY"),
#       5     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#       6 )
#       8 response = client.chat.completions.create(
#       9     model="gemini-1.5-flash",
#      10     n=1,
#    (...)
#      17     ]
#      18 )
#      20 print(response.choices[0].message)
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
# ...

# %%
from openai import OpenAI
import json

# Set your Google API key (replace 'your_google_api_key' with your actual API key)
os.environ["GOOGLE_API_KEY"] = "AIzaSyAXH-phHgbd_zdEBMxXuEf6NVwAEcxDB6U"

# Initialize the OpenAI client
client = OpenAI.ChatCompletion.create(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 8
#       5 os.environ["GOOGLE_API_KEY"] = "AIzaSyAXH-phHgbd_zdEBMxXuEf6NVwAEcxDB6U"
#       7 # Initialize the OpenAI client
# ----> 8 client = OpenAI.ChatCompletion.create(
#       9     api_key=os.getenv("GOOGLE_API_KEY"),
#      10     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#      11 )
#
# AttributeError: type object 'OpenAI' has no attribute 'ChatCompletion'

# %%
# !pip install openai

# %%
# !pip install openai==0.28

# %%
# Import required libraries
import os
from openai import OpenAI
import json

# %%
import os
from openai import OpenAI
import json

# Set your Google API key (replace 'your_google_api_key' with your actual API key)
os.environ["GOOGLE_API_KEY"] = "AIzaSyAXH-phHgbd_zdEBMxXuEf6NVwAEcxDB6U"

# Initialize the OpenAI client
client = OpenAI.ChatCompletion.create(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 9
#       6 os.environ["GOOGLE_API_KEY"] = "AIzaSyAXH-phHgbd_zdEBMxXuEf6NVwAEcxDB6U"
#       8 # Initialize the OpenAI client
# ----> 9 client = OpenAI.ChatCompletion.create(
#      10     api_key=os.getenv("GOOGLE_API_KEY"),
#      11     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#      12 )
#
# AttributeError: type object 'OpenAI' has no attribute 'ChatCompletion'

# %%
import os
from openai import OpenAI
import json

# Set your Google API key (replace 'your_google_api_key' with your actual API key)
os.environ["GOOGLE_API_KEY"] = "AIzaSyAXH-phHgbd_zdEBMxXuEf6NVwAEcxDB6U"

# %%
from openai import OpenAI
client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 from openai import OpenAI
# ----> 2 client = OpenAI(
#       3     api_key=os.getenv("GOOGLE_API_KEY"),
#       4     base_url="https://generativelanguage.googleapis.com/v1beta/openai"
#       5 )
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
#     124     version=__version__,
#     125     base_url=base_url,
#     126     max_retries=max_retries,
#     127     timeout=timeout,
#     128     http_client=http_client,
# ...

# %%
import os 
from google.colab import userdata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 2
#       1 import os
# ----> 2 from google.colab import userdata
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
from openai import OpenAI
client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai"
)

try:
    response = client.chat.completions.create(
        model="gemini-1.5-flash",
        messages=[
            {"role": "user", "content": "Explain to me how AI works"}
        ]
    )
    print(response.choices[0].message.content)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 from openai import OpenAI
# ----> 3 client = OpenAI(
#       4     api_key=os.getenv("GOOGLE_API_KEY"),
#       5     base_url="https://generativelanguage.googleapis.com/v1beta/openai"
#       6 )
#       8 try:
#       9     response = client.chat.completions.create(
#      10         model="gemini-1.5-flash",
#      11         messages=[
#      12             {"role": "user", "content": "Explain to me how AI works"}
#      13         ]
#      14     )
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
# ...

# %%
from openai import OpenAI

client = OpenAI(
    api_key="AIzaSyB9kViIfgLdu62K-kbE6f339pjxeYxGiZo",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
    # base_url=f"https://api.openai.com/v1"
)

response = client.chat.completions.create(
    model="gemini-1.5-flash",
    n=1,
  ---------------------------------------------------------------------------
  TypeError                                 Traceback (most recent call last)
  Cell In[12], line 1
  ----> 1 client = OpenAI(
        2             api_key=os.getenv("GOOGLE_API_KEY"),
        3             base_url="https://generativelanguage.googleapis.com/v1beta/"
        4         )
  
  File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
      120 if base_url is None:
      121     base_url = f"https://api.openai.com/v1"
  --> 123 super().__init__(
      124     version=__version__,
      125     base_url=base_url,
      126     max_retries=max_retries,
      127     timeout=timeout,
      128     http_client=http_client,
      129     custom_headers=default_headers,
      130     custom_query=default_query,
      131     _strict_response_validation=_strict_response_validation,
      132 )
      134 self._default_stream_cls = Stream
      136 self.completions = resources.Completions(self)
  
  File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_base_client.py:849, in SyncAPIClient.__init__(self, version, base_url, max_retries, timeout, transport, proxies, limits, http_client, custom_headers, custom_query, _strict_response_validation)
  ...
      745 kwargs.setdefault("limits", DEFAULT_CONNECTION_LIMITS)
      746 kwargs.setdefault("follow_redirects", True)
  --> 747 super().__init__(**kwargs)
  
  TypeError: Client.__init__() got an unexpected keyword argument 'proxies'
  Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
  ---------------------------------------------------------------------------
  TypeError                                 Traceback (most recent call last)
  Cell In[18], line 1
  ----> 1 client = OpenAI(
        2     api_key="AIzaSyB9kViIfgLdu62K-kbE6f339pjxeYxGiZo",
        3     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
        4 )
  
  File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
      120 if base_url is None:
      121     base_url = f"https://api.openai.com/v1"
  --> 123 super().__init__(
      124     version=__version__,
      125     base_url=base_url,
      126     max_retries=max_retries,
      127     timeout=timeout,
      128     http_client=http_client,
      129     custom_headers=default_headers,
      130     custom_query=default_query,
      131     _strict_response_validation=_strict_response_validation,
      132 )
      134 self._default_stream_cls = Stream
      136 self.completions = resources.Completions(self)
  
  File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_base_client.py:849, in SyncAPIClient.__init__(self, version, base_url, max_retries, timeout, transport, proxies, limits, http_client, custom_headers, custom_query, _strict_response_validation)
  ...
      745 kwargs.setdefault("limits", DEFAULT_CONNECTION_LIMITS)
      746 kwargs.setdefault("follow_redirects", True)
  --> 747 super().__init__(**kwargs)
  
  TypeError: Client.__init__() got an unexpected keyword argument 'proxies'
  Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
  ---------------------------------------------------------------------------
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Explain to me how AI works"
        }
    ]
)

print(response.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 from openai import OpenAI
# ----> 3 client = OpenAI(
#       4     api_key="AIzaSyB9kViIfgLdu62K-kbE6f339pjxeYxGiZo",
#       5     # base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#       6     base_url=f"https://api.openai.com/v1"
#       7 )
#       9 response = client.chat.completions.create(
#      10     model="gemini-1.5-flash",
#      11     n=1,
#    (...)
#      18     ]
#      19 )
#      21 print(response.choices[0].message)
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
# ...

# %%
client = OpenAI(
    api_key="AIzaSyB9kViIfgLdu62K-kbE6f339pjxeYxGiZo",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 client = OpenAI(
#       2     api_key="AIzaSyB9kViIfgLdu62K-kbE6f339pjxeYxGiZo",
#       3     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#       4 )
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
#     124     version=__version__,
#     125     base_url=base_url,
#     126     max_retries=max_retries,
#     127     timeout=timeout,
#     128     http_client=http_client,
#     129     custom_headers=default_headers,
# ...

# %%
client = OpenAI(
            api_key=os.getenv("GOOGLE_API_KEY"),
            base_url="https://generativelanguage.googleapis.com/v1beta/"
        )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 client = OpenAI(
#       2             api_key=os.getenv("GOOGLE_API_KEY"),
#       3             base_url="https://generativelanguage.googleapis.com/v1beta/"
#       4         )
#
# File c:\Users\Surface\Desktop\data-science-project\Coffe-Shop-Chatbot\python_code\venv\lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
#     124     version=__version__,
#     125     base_url=base_url,
#     126     max_retries=max_retries,
#     127     timeout=timeout,
#     128     http_client=http_client,
#     129     custom_headers=default_headers,
# ...

# %%
def get_chatbot_response(client,model_name,messages,temperature=0):
    input_messages = []
    for message in messages:
        input_messages.append({"role": message["role"], "content": message["content"]})

    response = client.chat.completions.create(
        model=model_name,
        messages=input_messages,
        temperature=temperature,
        top_p=0.8,
        max_tokens=2000,
    ).choices[0].message.content
    
    return response
